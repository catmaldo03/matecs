# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df_original=pd.read_csv("heart_failure_clinical_records_dataset.csv")
df_original.head(5)# muestra los primeros 5 resultados
df_new=df_original.describe()
#df['DEATH_EVENT'].value_counts()

# %%
fig,axes = plt.subplots(4,2,figsize=(15,30))
sns.boxplot(ax=axes[0][0],data= df_original, x='DEATH_EVENT',y='age',width=0.5)
sns.boxplot(ax=axes[0][1],data= df_original, x='DEATH_EVENT',y='creatinine_phosphokinase',width=0.5)
sns.boxplot(ax=axes[1][0],data= df_original, x='DEATH_EVENT',y='ejection_fraction',width=0.5)
sns.boxplot(ax=axes[1][1],data= df_original,x='DEATH_EVENT',y='platelets',width=0.5)
sns.boxplot(ax=axes[2][0],data= df_original, x='DEATH_EVENT',y='serum_creatinine',width=0.5)
sns.boxplot(ax=axes[2][1],data= df_original, x='DEATH_EVENT',y='serum_sodium',width=0.5)
sns.boxplot(ax=axes[3][0],data= df_original, x='DEATH_EVENT',y='time',width=0.5)
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='time'>

# %%
def enconding_by_OneHot(dataframe, column):
    matrix_coding=[]
    for index in dataframe.index:
        value_defo=dataframe[column][index]
        if index.data ==0:
            matrix_coding.append([1,0])
        else:
